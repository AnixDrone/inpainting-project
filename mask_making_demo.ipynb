# %%
from img_data_class import ImageDataset
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import make_grid
import torch
from torch import nn
import matplotlib.pyplot as plt
from model_class import ConditionalVAE
import torch.optim as optim
import torch.nn.functional as F
import tqdm
import numpy

# %%
tr = transforms.Compose(
    [
     transforms.Resize((256,256)),
     transforms.ToTensor(),
    #  transforms.Normalize(
    #        [0.5 for _ in range(1)], [0.5 for _ in range(1)]),
    ],
    )

# %%
train = ImageDataset('data/train',tr)

# %%
train_dl = DataLoader(train,5,shuffle=True)

# %%
for img in train_dl:
    plt.imshow(make_grid(img).permute(1,2,0))
    break

# %%
tr_img = transforms.RandomErasing(1)

# %%
tr_img_tensor = [tr_img(i) for i in img]

# %%
torch.stack(tr_img_tensor).shape
# Out:
# torch.Size([5, 3, 256, 256])

# %%
plt.imshow(make_grid(tr_img_tensor).permute(1,2,0))
